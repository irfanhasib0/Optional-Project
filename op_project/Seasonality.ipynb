# %%
import pickle
import pandas as pd
from matplotlib import pyplot as plt
pickle_out = open("df_mean_sb.pickle","rb")
df=pickle.load(pickle_out)
pickle_out.close()

# %%
#df['qc']=qc_names

#df=df.rolling(window=50).mean()


df[:200].plot()
#df.to_csv(root+'lai_fpar_all.csv',sep=',')
#print(df[:100])

# %%
df.head()
# Out:
#                    qc        Lai       Fapr
# 2005-01-01  16.612483  10.930991  25.809168
# 2005-01-05  16.813890  10.744619  25.780916
# 2005-01-09  15.680287  11.058824  25.656399
# 2005-01-13  16.599551   7.787809  22.462057
# 2005-01-17  14.525251  10.992426  25.634523
